# %% [markdown]
# # Model Packaging & Reproducibility
#
# ## Objective
#
# In this section, the trained machine learning model and preprocessing pipeline are packaged for reuse during inference and deployment. This ensures reproducibility by saving the trained model, preprocessing components, and project dependencies required to recreate the machine learning environment.

# %%
import joblib
import os

print("Libraries imported successfully.")
# Out:
# Libraries imported successfully.

# %%
# Create models folder if it doesn't exist

os.makedirs("../models", exist_ok=True)

print("Models directory is ready.")
# Out:
# Models directory is ready.

# %% [markdown]
# ## Load the Saved Model
#
# The trained Random Forest model is loaded from the models directory to verify that it has been successfully packaged and can be reused for inference without retraining.

# %%
import joblib

# Load the saved model
model = joblib.load("../models/heart_disease_model.pkl")

print("Model loaded successfully!")
print(model)
# Out:
# Model loaded successfully!
# RandomForestClassifier(max_depth=5, min_samples_split=5, random_state=42)

# %%
print(type(model))
# Out:
# <class 'sklearn.ensemble._forest.RandomForestClassifier'>

# %%
print("Model Details:\n")

print(model)
# Out:
# Model Details:
#
# RandomForestClassifier(max_depth=5, min_samples_split=5, random_state=42)

# %%
import joblib

# Load model
model = joblib.load("../models/heart_disease_model.pkl")

print("Model loaded successfully!")
print(type(model))
# Out:
# Model loaded successfully!
# <class 'sklearn.ensemble._forest.RandomForestClassifier'>

# %%
import pandas as pd

df = pd.read_csv("../data/processed/heart.csv")

df.head()
# Out:
#     age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1  67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2  67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3  37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4  41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
#
#    slope   ca  thal  target
# 0    3.0  0.0   6.0       0
# 1    2.0  3.0   3.0       1
# 2    2.0  2.0   7.0       1
# 3    3.0  0.0   3.0       0
# 4    1.0  0.0   3.0       0

# %%
# Separate Feature & Target

X = df.drop("target", axis=1)
y = df["target"]

# %%
sample = X.iloc[[0]]

prediction = model.predict(sample)

print("Prediction:", prediction[0])
# Out:
# Prediction: 0

# %%
probability = model.predict_proba(sample)

print("Prediction Probability:")
print(probability)
# Out:
# Prediction Probability:
# [[0.68905764 0.31094236]]

# %%
import sys
import os

# Add the project root to Python path
sys.path.append(os.path.abspath(".."))

print(sys.path[-1])
# Out:
# c:\Projects\Heart-Disease-MLOps

# %%
from src.predict import predict_heart_disease

# %%
from src.predict import predict_heart_disease

sample = [
    63, 1, 3, 145, 233,
    1, 0, 150, 0,
    2.3, 0, 0, 1
]

prediction, probability = predict_heart_disease(sample)

print("Prediction:", prediction)
print("Probability:", probability)
# Out:
# Prediction: 0
# Probability: 0.24484949091133273
